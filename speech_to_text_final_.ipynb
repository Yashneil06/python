# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashneil06/python/blob/week4/speech_to_text_final_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition
# Out:
# ...
#      |████████████████████████████████| 32.8 MB 1.4 MB/s
# ...

# %%
# !wget https://www.pacdv.com/sounds/voices/thank-god-its-friday.wav
# Out:
# --2022-03-27 12:07:57--  https://www.pacdv.com/sounds/voices/thank-god-its-friday.wav
# Resolving www.pacdv.com (www.pacdv.com)... 192.232.218.187
# Connecting to www.pacdv.com (www.pacdv.com)|192.232.218.187|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 412088 (402K) [audio/x-wav]
# Saving to: ‘thank-god-its-friday.wav’
#
# thank-god-its-frida 100%[===================>] 402.43K  1.48MB/s    in 0.3s
#
# 2022-03-27 12:07:58 (1.48 MB/s) - ‘thank-god-its-friday.wav’ saved [412088/412088]

# %%
import IPython
file = 'thank-god-its-friday.wav'
IPython.display.Audio(file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import speech_recognition as sr 
r = sr.Recognizer()

with sr.AudioFile(file) as source:
  audio_data = r.record(source)
  text = r.recognize_google(audio_data)
  print(text)
# Out:
# thank God it's Friday
